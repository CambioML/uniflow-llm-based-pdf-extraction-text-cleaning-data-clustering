# %% [markdown]
# # Example of generating QAs for a 10K
# In this example, we will show you how to generate question-answers (QAs) from a pdf using OpenAI's models via `uniflow`'s [OpenAIJsonModelFlow](https://github.com/CambioML/uniflow/blob/main/uniflow/flow/model_flow.py#L125).
#
# For this example, we're using a [10K from Nike](https://investors.nike.com/investors/news-events-and-reports/).
#
# ### Before running the code
#
# You will need to `uniflow` conda environment to run this notebook. You can set up the environment following the instruction: https://github.com/CambioML/uniflow/tree/main#installation.
#
# Next, you will need a valid [OpenAI API key](https://platform.openai.com/api-keys) to run the code. Once you have the key, set it as the environment variable `OPENAI_API_KEY` within a `.env` file in the root directory of this repository. For more details, see this [instruction](https://github.com/CambioML/uniflow/tree/main#api-keys)
#
# Finally, we are storing the Nike 10K in the `data\raw_input` directory as "nike-10k-2023.pdf". You can download the file from [here](https://s1.q4cdn.com/806093406/files/doc_downloads/2023/414759-1-_5_Nike-NPS-Combo_Form-10-K_WR.pdf).

# %% [markdown]
# ### Update system path

# %%
# %reload_ext autoreload
# %autoreload 2

import sys

sys.path.append(".")
sys.path.append("..")
sys.path.append("../..")

# %% [markdown]
# ### Install helper packages

# %%
# !{sys.executable} -m pip install -q python-dotenv openai
# !{sys.executable} -m pip uninstall -y uniflow
# Out:
# WARNING: Skipping uniflow as it is not installed.

# %% [markdown]
# ### Import Dependency

# %%
from dotenv import load_dotenv
from uniflow.flow.client import TransformClient
from uniflow.flow.config import TransformOpenAIConfig, TransformForGenerationOpenAIGPT3p5Config
from uniflow.op.model.model_config import OpenAIModelConfig
from uniflow.op.prompt import Context, PromptTemplate

load_dotenv()
# Out:
# True

# %% [markdown]
# ### Prepare sample prompts
#
# First, we need to demonstrate sample prompts for LLM. We do this by giving a sample list of `Context` examples to the `PromptTemplate` class.

# %%
guided_prompt = PromptTemplate(
    instruction="""Generate one question and its corresponding answer based on the last context in the last
    example. Follow the format of the examples below to include context, question, and answer in the response""",
    few_shot_prompt=[
        Context(
            context="In 1948, Claude E. Shannon published A Mathematical Theory of\nCommunication (Shannon, 1948) establishing the theory of\ninformation. In his article, Shannon introduced the concept of\ninformation entropy for the first time. We will begin our journey here.",
            question="Who published A Mathematical Theory of Communication in 1948?",
            answer="Claude E. Shannon.",
        ),
        Context(
            context="""The Compute & Networking segment is comprised of our Data Center accelerated computing platforms and end-to-end networking platforms including Quantum
for InfiniBand and Spectrum for Ethernet; our NVIDIA DRIVE automated-driving platform and automotive development agreements; """,
            question="What does the Compute & Networking segment include?",
            answer="""The Compute & Networking segment includes Data Center accelerated computing platforms, end-to-end networking platforms (Quantum for InfiniBand and Spectrum for Ethernet), the NVIDIA DRIVE automated-driving platform, and automotive development agreements.""",
        ),
])

# %% [markdown]
# Next, for the given `page_contents` above, we convert them to the `Context` class to be processed by `uniflow`.

# %% [markdown]
# ### Use LLM to generate data
#
# In this example, we will use the [OpenAIModelConfig](https://github.com/CambioML/uniflow/blob/main/uniflow/model/config.py#L17)'s default LLM to generate questions and answers.
#
# Here, we pass in our `guided_prompt` to the `OpenAIConfig` to use our customized instructions and examples, instead of the `uniflow` default ones.
#
# We also want to get the response in the `json` format instead of the `text` default, so we set the `response_format` to `json_object`.

# %%
# config = TransformOpenAIConfig(
#     prompt_template=guided_prompt,
#     model_config=OpenAIModelConfig(response_format={"type": "text"}),
#     # auto_split_long_text=False
# )

config2 = TransformForGenerationOpenAIGPT3p5Config(
    prompt_template=guided_prompt,
    model_config=OpenAIModelConfig(),
    auto_split_long_text=True
)

client = TransformClient(config2)

# %%
# def read_and_chunk(file_path, words_per_chunk=2500):
#     # Initialize variables
#     contexts = []
#     current_chunk_words = []

#     # Open and read the file
#     with open(file_path, 'r', encoding='utf-8') as file:
#         for line in file:
#             # Split the line into words
#             words = line.split()
#             for word in words:
#                 current_chunk_words.append(word)
#                 # Check if the current chunk reached the specified number of words
#                 if len(current_chunk_words) >= words_per_chunk:
#                     # Join the words to form a context and add to the list
#                     contexts.append(Context(context=' '.join(current_chunk_words)))
#                     current_chunk_words = []  # Reset for the next chunk

#     # Add the last chunk if there are any remaining words
#     if current_chunk_words:
#         contexts.append(Context(context=' '.join(current_chunk_words)))

#     return contexts

# # Example usage
# file_path = './data/raw_input/book-war-and-peace.txt'
# contexts = read_and_chunk(file_path)
# for context in contexts[:1]:  # Just printing the first Context for brevity
#     print(f"---\nContext(context='{context.context[:50]}...')\n---")

# %%
def extract_contexts(file_path, ranges):
    # Read the entire file content
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Initialize the list for holding contexts
    contexts = []

    # Extract specified ranges
    for start, end in ranges:
        # Adjusting end index to fit within the file length if necessary
        end = min(end, len(content))
        context_text = content[start:end]
        contexts.append(Context(context=context_text))

    return contexts

# Define the ranges for the contexts
ranges = [(100, 992000), (992000+12600, 992000+13200)]

# Specify the file path
file_path = './data/raw_input/book-war-and-peace.txt'

# Extract contexts
contexts = extract_contexts(file_path, ranges)

# Print the contexts for demonstration
for i, context in enumerate(contexts):
    preview_text = context.context[:50] + "..." if len(context.context) > 50 else context.context
    print(f"---\nContext {i+1} (Preview): '{preview_text}'\n---")
# Out:
# ---
# Context 1 (Preview): 'arn you, if you don't tell me that this means war,...'
# ---
# ---
# Context 2 (Preview): 'e said
# to Pierre as he kissed her hand. She had kn...'
# ---

# %% [markdown]
# Now we call the `run` method on the `client` object to execute the question-answer generation operation on the data shown above.

# %%
# print(contexts[0])

output = client.run(contexts[:15])
# Out:
# The current Context object needs splitting because it exceeds the token limitation.
# 9782
# 9873
# 9817
# 9715
# 9864
# 9957
# 9927
# 9317
# 9607
# 9732
# 9562
# 9968
# 9796
# 9744
# 8175
# 9809
# 9998
# 9883
# 9803
# 9589
# 8727
# 8528
# 9631
# 9908
# 9692
# 9826
# 9791
# 9933
# 9496
# 9951
# 9760
# 9941
# 9995
# 9934
# 9931
# 9418
# 9922
# 9579
# 8898
# 9880
# 9994
# 8807
# 9898
# 9809
# 9600
# 9541
# 9844
# 9292
# 9326
# 9888
# 9488
# 9395
# 8969
# 9569
# 9950
# 9962
# 9947
# 9848
# 9919
# 9604
# 9833
# 9295
# 9884
# 9704
# 9803
# 9938
# 9717
# 9891
# 9938
# 9785
# 9503
# 9434
# 9738
# 9827
# 9940
# 9968
# 9743
# 10000
# 9786
# 9212
# 7587
# 9176
# 9456
# 9931
# 9920
# 9759
# 9985
# 9991
# 9989
# 9885
# 9988
# 9713
# 9474
# 9788
# 9482
# 9578
# 9884
# 9684
# 9760
# 9595
# 9818
# 7133
# 100%|██████████| 103/103 [01:49<00:00,  1.06s/it]

# %% [markdown]
# ### Output

# %%
from pprint import pprint
pprint(len(output))

pprint(output[0])

for o in output:
    pprint(o['output'][0]['response'])
# Out:
# 103
# {'output': [{'error': 'No errors.',
#              'response': ['question: Who was the speaker in the last context?\n'
#                           'answer: The speaker in the last context was Anna '
#                           'Pavlovna Scherer.']}],
#  'root': <uniflow.node.Node object at 0x1227b48b0>}
# ['question: Who was the speaker in the last context?\n'
#  'answer: The speaker in the last context was Anna Pavlovna Scherer.']
# ['question: Who is the beautiful Princess Helene in the context?\n'
#  "answer: The beautiful Princess Helene is Prince Vasili's daughter."]
# ['question: Who entered the drawing room in the last part of the context?\n'
#  'answer: Prince Andrew Bolkonski.']
# ['question: Who published A Mathematical Theory of Communication in 1948?\n'
#  'answer: Claude E. Shannon.']
# ['question: What did Prince Hippolyte say he was glad he did not go to?\n'
#  'answer: Prince Hippolyte said he was very glad he did not go to the '
#  "ambassador's as it was dull."]
# ['question: Who did Prince Andrew catch by the hand at the end of the '
#  'passage?\n'
#  'answer: Pierre.']
# ['question: Who is the main character in the context provided?\n'
#  'answer: The main character in the context provided is Pierre.']
# ['question: Who was the notorious gambler and duelist living with Anatole?\n'
#  'answer: Dolokhov, an officer of the Semenov regiment.']
# ['question: Who is Prince Vasili coming to visit in Moscow?\n'
#  'answer: Prince Vasili is coming to see Count Cyril Vladimirovich, who is '
#  'very ill.']
# ['question: What did the countess say about bringing up children?\n'
#  'answer: The countess remarked that "It all depends on the bringing up" in '
#  'reference to the behavior of young people.']
# ['question: What does Natasha accuse Vera of doing with Boris?\n'
#  'answer: Natasha accuses Vera of behaving improperly with Boris.']
# ["question: Who is seated in Countess Rostova's carriage as they drive to "
#  "Count Cyril Vladimirovich Bezukhov's house?\n"
#  'answer: Princess Anna Mikhaylovna and her son, Boris.']
# ['question: How was Pierre received by the princesses and Boris?\n'
#  'answer: Pierre was received poorly by the princesses, who were cold and '
#  'unenthusiastic in their greeting. When he mistook Boris for Ilya and spoke '
#  'of a shared memory, Boris corrected him and responded sarcastically.']
# ['question: What was Countess Rostova known for in society?\n'
#  'answer: Countess Rostova was known in society as "le terrible dragon," a '
#  'lady distinguished for her common sense and frank plainness of speech.']
# ['question: Who criticized Pierre for setting a policeman astride a bear?\n'
#  'answer: Marya Dmitrievna']
# ['question: Who was present at the dinner and what were their interactions?\n'
#  'answer: The dinner guests included the count, countess, army colonel, '
#  'Shinshin, Anna Mikhaylovna, Julie Karagina, Nicholas, Vera, Berg, Pierre, '
#  'Boris, Sonya, tutors, and governesses. The dinner featured discussions about '
#  'the declaration of war, with the colonel sharing his patriotic views, and '
#  'lighthearted banter among the guests. Natasha and her little brother engaged '
#  'in playful mischief and teasing.']
# ["question: What was the name of the count's favorite dance?\n"
#  "answer: The count's favorite dance was the Daniel Cooper, which he had "
#  'danced in his youth.']
# ['question: Who was the count dancing with?\n'
#  'answer: The count was dancing with Marya Dmitrievna.']
# ['question: Why did Pierre hesitate about going to the count?\n'
#  'answer: Pierre hesitated about going to the count because he did not know if '
#  'the count had asked for him, so he considered going to his own room.']
# ['question: Who was lying in the large room, covered by a bright green quilt, '
#  'and surrounded by priests conducting a service?\n'
#  "answer: Count Bezukhov, Pierre's father, was lying in the large room, "
#  'covered by a bright green quilt, and surrounded by priests conducting a '
#  'service.']
# ['question: Who were the only people left in the reception room?\n'
#  'answer: The only people left in the reception room were Prince Vasili and '
#  'the eldest princess.']
# ["question: Who was responsible for telling Pierre about his father's death in "
#  'the morning?\n'
#  'answer: Anna Mikhaylovna was responsible for telling Pierre about his '
#  "father's death in the morning."]
# ['question: Who was the arrival daily expected at Bald Hills?\n'
#  'answer: The arrival daily expected at Bald Hills was young Prince Andrew and '
#  'his wife.']
# ['question: What did Princess Mary and Mademoiselle Bourienne do before the '
#  'conversation mentioned?\n'
#  'answer: Princess Mary and Mademoiselle Bourienne were writing letters.']
# ['question: Who went into the sitting room with a look of alarm after seeing '
#  'that she was five minutes late in starting her practice on the clavichord?\n'
#  'answer: The princess went into the sitting room with a look of alarm.']
# ["question: What is the old prince's opinion of Bonaparte and his military "
#  'abilities?\n'
#  'answer: The old prince believes that Bonaparte is an insignificant little '
#  'Frenchy, successful only because there were no longer any significant '
#  'commanders like Potemkins or Suvorovs left to oppose him. He also thinks '
#  'that Bonaparte made blunders in his campaigns and in politics, despite his '
#  'reputation as a great general.']
# ["question: What did Prince Andrew's sister say to him about her father-in-law "
#  'and her husband?\n'
#  'answer: She had spoken to him about her forebodings about her confinement, '
#  'and how she dreaded it, and had complained of her fate, her father-in-law, '
#  'and her husband.']
# ['question: What was the appearance of the infantry regiment that had just '
#  'reached Braunau on October 11, 1805?\n'
#  'answer: Despite the un-Russian appearance of the locality and surroundings, '
#  'the regiment had just the appearance of any Russian regiment preparing for '
#  'an inspection anywhere in the heart of Russia.']
# ['question: Who was the regimental commander, and what instructions did he '
#  'give to his troops?\n'
#  'answer: The regimental commander was an elderly, stout general. He ordered '
#  'the soldiers to change into their greatcoats.']
# ['question: Who were the people sitting in the high, light blue Viennese '
#  'caleche drawn by six horses?\n'
#  'answer: Kutuzov and an Austrian general were sitting in the high, light blue '
#  'Viennese caleche drawn by six horses.']
# ['question: Who visited Kutuzov to discuss the condition of the troops after '
#  'returning from the review?\n'
#  'answer: The Austrian general visited Kutuzov to discuss the condition of the '
#  'troops after returning from the review.']
# ["question: What was Prince Andrew's reaction upon receiving news of Mack's "
#  'defeat?\n'
#  'answer: Prince Andrew felt a joyful agitation at the thought of the '
#  'humiliation of arrogant Austria and the upcoming Russian encounter with the '
#  'French. He was excited and irritated by the news and went to write a letter '
#  'to his father.']
# ['question: Who did Rostov ask Lavrushka about when he entered the room?\n'
#  'answer: Rostov asked Lavrushka about his master, Denisov.']
# ["question: Who was involved in the discussion among the squadron's officers "
#  "in Denisov's quarters?\n"
#  "answer: The squadron's officers involved in the discussion were Rostov, the "
#  'staff captain, Kirsten, and Denisov.']
# ['question: What did Prince Nesvitski see when he looked down over the rails '
#  'of the bridge?\n'
#  'answer: Prince Nesvitski saw the rapid, noisy little waves of the Enns, '
#  'soldiers crowded together, shoulder straps, covered shakos, knapsacks, '
#  'bayonets, long muskets, and faces with broad cheekbones, sunken cheeks, and '
#  'listless tired expressions, as well as officers and baggage wagons moving '
#  'across the bridge.']
# ['question: What group of troops in blue uniform were seen on the road at the '
#  'top of the high ground?\n'
#  'answer: The French troops in blue uniform were seen on the road at the top '
#  'of the high ground.']
# ['question: What did Rostov stumble on as he tried to be ahead of the others?\n'
#  'answer: Rostov stumbled on some sticky, trodden mud as he ran towards the '
#  'bridge.']
# ['question: What actions had the Russian army fought at Lambach, Amstetten, '
#  'and Melk?\n'
#  'answer: The Russian army had fought rearguard actions at Lambach, Amstetten, '
#  'and Melk.']
# ['question: Who was Prince Andrew in attendance on during the battle?\n'
#  'answer: Prince Andrew had been in attendance on the Austrian General Schmidt '
#  'during the battle.']
# ['question: Who was conversing with Prince Andrew and expressed his belief '
#  'that Austria was being deceived and that negotiations with France and peace '
#  'projects were underway?\n'
#  'answer: Bilibin.']
# ['question: Who mentioned the Thabor Bridge affair in Vienna?\n'
#  'answer: Bilibin mentioned the Thabor Bridge affair in Vienna.']
# ['question: What are some of the reports that Prince Andrew hears about the '
#  'Russian army?\n'
#  "answer: Prince Andrew hears very sinister reports of the army's position and "
#  "the troops' disorderly flight."]
# ['question: Who was Prince Andrew trying to find in the village?\n'
#  'answer: Prince Andrew was trying to find the commander-in-chief in the '
#  'village.']
# ['question: What did Prince Andrew request from Kutuzov?\n'
#  'answer: Prince Andrew persisted in his request to Kutuzov to be sent to that '
#  'detachment.']
# ['question: Who was the staff officer speaking to and what was he scolding '
#  'them for?\n'
#  'answer: The staff officer was speaking to Captain Tushin, scolding him for '
#  'not being at his post and not wearing his boots.']
# ['question: What did Bagration do when he arrived at the scene and what was '
#  'his reaction?\n'
#  'answer: When Bagration arrived, he reined in his horse and recognized Prince '
#  'Andrew, nodding to him. His hard brown face displayed an expression of "It '
#  'has begun! Here it is!" signifying the commencement of the battle.']
# ['question: What is included in the Compute & Networking segment?\n'
#  'answer: The Compute & Networking segment includes Data Center accelerated '
#  'computing platforms, end-to-end networking platforms (Quantum for InfiniBand '
#  'and Spectrum for Ethernet), the NVIDIA DRIVE automated-driving platform, and '
#  'automotive development agreements.']
# ['question: Who was the commander of the regiment that turned to Prince '
#  'Bagration and what did he entreat him to do?\n'
#  'answer: The commander of the regiment that turned to Prince Bagration '
#  'entreated him to go back as it was too dangerous to remain where they were.']
# ["question: What sparked the general's realization that something dreadful had "
#  'happened to his regiment?\n'
#  'answer: The moment he heard the firing and the cry from behind.']
# ['question: Who led the Russian sharpshooters that showed themselves in the '
#  'copse and attacked the French unexpectedly?\n'
#  'answer: Timokhin led the Russian sharpshooters that showed themselves in the '
#  'copse and attacked the French unexpectedly.']
# ['question: Who was sitting at dinner in the hut that had been prepared for '
#  'him?\n'
#  'answer: Prince Bagration.']
# ['question: What kind of man was Prince Vasili and what was the whole interest '
#  'of his life?\n'
#  'answer: Prince Vasili was a man of the world who had gotten on and to whom '
#  'getting on had become a habit. The whole interest of his life was constantly '
#  'shaping schemes and devices in his mind, arising from the circumstances and '
#  'persons he met.']
# ['question: Who did Pierre spend most of his time with in Petersburg?\n'
#  "answer: Pierre spent most of his time in Petersburg at Prince Vasili's house "
#  'in the company of the princess, his wife, and his beautiful daughter Helene.']
# ['question: In November 1805, where did Prince Vasili have to go on a tour of '
#  'inspection?\n'
#  'answer: Prince Vasili had to go on a tour of inspection in four different '
#  'provinces.']
# ['question: Who dominated the center of attention at the gathering in Prince '
#  "Vasili's house during Helene's name day?\n"
#  'answer: The simple feeling of the attraction of a healthy and handsome young '
#  'man and woman for one another.']
# ['question: Who received a letter from Prince Vasili in November, 1805?\n'
#  'answer: Old Prince Nicholas Bolkonski received a letter from Prince Vasili '
#  'in November, 1805.']
# ['question: Who arrived that evening at the avenue?\n'
#  'answer: Prince Vasili arrived that evening.']
# ["question: Who did the little princess ask why he was never at Annette's?\n"
#  "answer: The little princess asked Anatole why he was never at Annette's."]
# ['question: Who does Prince Vasili present to Prince Bolkonski as his second '
#  'son?\n'
#  'answer: Prince Vasili presents Anatole to Prince Bolkonski as his second '
#  'son.']
# ['question: Who was the old prince expecting would propose to his daughter as '
#  'a daughter-in-law?\n'
#  "answer: Prince Vasili was expected to propose to the old prince's daughter "
#  'on behalf of his pupil.']
# ['question: Who does Natasha remember well and who does she not remember?\n'
#  'answer: Natasha remembers Nikolenka well, but she does not remember Boris at '
#  'all.']
# ['question: What did Rostov receive in a letter from Boris?\n'
#  'answer: Rostov received a letter from Boris, telling him that the Ismaylov '
#  'regiment was quartered for the night ten miles from Olmutz and that he '
#  'wanted to see him as he had a letter and money for him.']
# ['question: Who did Boris and Berg tell Rostov about, and what did they say '
#  'about him?\n'
#  'answer: Boris and Berg told Rostov about their commander, the Grand Duke, '
#  'and spoke of his kindness and irascibility. Berg related a story of how he '
#  'managed to deal with the Grand Duke and prove he was right, impressing '
#  'Rostov.']
# ['question: Who inspected the allied army of eighty thousand men?\n'
#  'answer: The two Emperors, the Russian with his heir the Tsarevich, and the '
#  'Austrian with the Archduke, inspected the army.']
# ["question: What did Prince Andrew's expression convey when Boris entered the "
#  'room?\n'
#  "answer: Prince Andrew's expression conveyed a polite weariness that "
#  'suggested if it were not his duty to talk to Boris, he would not do so for '
#  'even a moment.']
# ['question: Who nodded to Dolgorukov and stared at Prince Andrew with cool '
#  'intensity?\n'
#  'answer: The short man in civilian clothes with a clever face and a sharply '
#  'projecting jaw nodded to Dolgorukov and stared at Prince Andrew with cool '
#  'intensity.']
# ['question: Who was the Emperor that Rostov and his fellow soldiers were '
#  'waiting for?\n'
#  'answer: The Emperor that Rostov and his fellow soldiers were waiting for was '
#  'Alexander the First.']
# ['question: What was Prince Andrew unable to refrain from asking Kutuzov as '
#  'they were on the way home?\n'
#  'answer: Prince Andrew could not refrain from asking Kutuzov what he thought '
#  "of tomorrow's battle."]
# ["question: What is the commander-in-chief's name in this context?\n"
#  'answer: Kutuzov.']
# ['question: Who appeared out of the foggy darkness and spoke with Rostov?\n'
#  'answer: A sergeant of hussars.']
# ['question: What did the soldiers do when the Austrian column guides began '
#  'moving in and out among the Russian troops and served as heralds of the '
#  'advance?\n'
#  'answer: When the Austrian column guides moved in and out among the Russian '
#  'troops and served as heralds of the advance, the soldiers ran from the '
#  'fires, thrust their pipes into their boots, their bags into the carts, got '
#  'their muskets ready, and formed rank. The officers buttoned up their coats, '
#  'buckled on their swords and pouches, and moved along the ranks shouting. The '
#  'train drivers and orderlies harnessed and packed the wagons and tied on the '
#  'loads.']
# ['question: What did the French army do when they began their action?\n'
#  'answer: The French army began moving rapidly toward the Pratzen Heights, '
#  'which were being more and more denuded by Russian troops moving down the '
#  'valley to their left.']
# ['question: Where was the sound of regiments saluting coming from?\n'
#  'answer: The sound of regiments saluting was heard at a distance behind '
#  'Kutuzov.']
# ['question: At what time had the battle on the right flank not yet begun?\n'
#  "answer: At nine o'clock."]
# ['question: What did Rostov see happening as he rode into the region behind '
#  'the village of Pratzen?\n'
#  'answer: Rostov saw Russian and Austrian soldiers running in confused crowds, '
#  'firing at one another, and several wounded men passing along the road.']
# ['question: Who was seen riding up to the Emperor and offering his services in '
#  'the field of battle?\n'
#  'answer: Captain von Toll.']
# ['question: Who lay bleeding and unconscious on the Pratzen Heights?\n'
#  'answer: Prince Andrew Bolkonski']
# ["question: Who was introduced to the count as Vasili Denisov's son's friend?\n"
#  "answer: Denisov introduced himself to the count as Vasili Denisov's son's "
#  'friend.']
# ['question: How did Rostov feel after meeting Natasha and Sonya?\n'
#  'answer: Rostov felt unsure of how to behave with Sonya, but exchanged tender '
#  'kisses with her while exchanging glances that expressed thanks for her '
#  'understanding and for offering him his freedom. He also felt a sense of '
#  "discomfort due to Vera's observation about Sonya and Nicholas."]
# ['question: What event are they arranging a dinner for at the English Club?\n'
#  'answer: A dinner in honor of Prince Bagration.']
# ['question: What was the general atmosphere in the English Club on March 3rd?\n'
#  'answer: The rooms in the English Club on March 3rd were filled with a hum of '
#  'conversation, featuring a mix of elderly and young people, with the younger '
#  'military men displaying a condescending respect for their elders, and the '
#  "older members surrounded by an atmosphere of subservience to Pierre's "
#  'wealth. In the third circle, members like Naryshkin, Rostopchin, and Valuev '
#  'shared stories and conversations about the events during the war.']
# ['question: What was the nature of the problem that tormented Pierre during '
#  'dinner?\n'
#  'answer: The problem that tormented Pierre during dinner was caused by hints '
#  "given by his cousin, the princess, at Moscow, concerning Dolokhov's intimacy "
#  'with his wife, and by an anonymous letter he had received that morning.']
# ['question: Who were the people involved in the duel?\n'
#  'answer: The people involved in the duel were Pierre, Dolokhov, Rostov, '
#  'Denisov, and Nesvitski.']
# ['question: Who did Pierre see lying in the snow with a forced smile, and what '
#  'did his wife say to him about having children?\n'
#  'answer: Pierre saw Dolokhov sitting in the snow with a forced smile. His '
#  'wife laughed contemptuously and said she was not a fool to want to have '
#  'children and was not going to have any children by Pierre.']
# ['question: What event has happened that brought great sorrow to Princess '
#  "Mary's family?\n"
#  'answer: The news of the death of Prince Andrew at the battle of Austerlitz '
#  "has brought great sorrow to Princess Mary's family. His body has not been "
#  'found, and there is still a possibility that he is lying, recovering, or '
#  'dying alone among strangers and unable to send news of himself.']
# ['question: Who arrived at the house in a carriage with lanterns and embraced '
#  'his sister, Princess Mary?\n'
#  'answer: Prince Andrew arrived at the house in a carriage with lanterns and '
#  'embraced his sister, Princess Mary.']
# ["question: What was the result of Rostov's involvement in the duel between "
#  'Dolokhov and Bezukhov?\n'
#  'answer: The efforts of the old count hushed up the matter and instead of '
#  'being degraded, Rostov was appointed an adjutant to the governor general of '
#  'Moscow.']
# ['question: Who was in love with Sonya and had proposed to her?\n'
#  'answer: Dolokhov both proposed to and was in love with Sonya.']
# ['question: What did Dolokhov say in the note he sent to Rostov?\n'
#  'answer: Dolokhov said, "As I do not intend to be at your house again for '
#  'reasons you know of, and am going to rejoin my regiment, I am giving a '
#  'farewell supper tonight to my friends--come to the English Hotel."']
# ['question: What are the names of the Rostov sisters?\n'
#  'answer: The Rostov sisters are Sonya and Natasha.']
# ['question: Who did the countess think Denisov should have addressed himself '
#  'to first before proposing to Natasha?\n'
#  "answer: The countess thought that, as her son's friend, Denisov should have "
#  'addressed herself first, before proposing to Natasha.']
# ['question: Who was the stranger that Pierre encountered at the post station?\n'
#  'answer: The stranger was an old man who was a member of the Freemasons.']
# ['question: What was the advice given to Pierre to do once he reaches '
#  'Petersburg?\n'
#  'answer: The advice given to Pierre was to devote some time to solitude and '
#  'self-examination and to not resume his former way of life.']
# ['question: What was the chief aim of the Order as described by the Rhetor in '
#  'his conversation with Pierre?\n'
#  'answer: The chief aim of the Order was the preservation and handing on to '
#  'posterity of a certain important mystery. It is a mystery on which perhaps '
#  'the fate of mankind depends, and it has come down to the Order from the '
#  'remotest ages, even from the first man.']
# ['question: What is the purpose of the seven large candlesticks in the room?\n'
#  'answer: The seven large candlesticks are used to light the room and are '
#  'similar to those used in churches.']
# ["question: What did Prince Vasili express about Pierre's mental state?\n"
#  'answer: Prince Vasili expressed his opinion that Pierre was "a bit touched" '
#  'and had always said so.']
# ['Question: Who received a snuffbox with a portrait as a reward the previous '
#  'year?\n'
#  'Answer: N-- N-- received a snuffbox with a portrait as a reward the previous '
#  'year.']
# ['question: What title did Claude E. Shannon publish in 1948?\n'
#  'answer: A Mathematical Theory of Communication.']
# ['question: What happens in the nursery while Prince Andrew is reading the '
#  'letter?\n'
#  'answer: The nurse is hiding something from him with a scared look, and '
#  'Princess Mary is no longer by the cot. When he went in, it seemed to him '
#  'that her whisper behind him was despairing.']
# ['question: What were some of the changes that young Count Pierre initiated on '
#  'his estates?\n'
#  'answer: Count Pierre initiated the building of hospitals, schools, and '
#  "asylums on all his estates, along with the reduction of the serfs' manorial "
#  'labor. He also released women from hard work and provided religious '
#  'instruction for children.']
# ["question: What is the significance of Pierre's visit to a village in South "
#  'Russia?\n'
#  "answer: The significance of Pierre's visit to a village in South Russia is "
#  'to reconnect with his friend Bolkonski who he had not seen in two years.']
# ['\n'
#  'question: What did Prince Andrew say he had promised himself not to do '
#  'again?\n'
#  'answer: Prince Andrew promised himself not to serve again in the active '
#  'Russian army.']
# ['question: What was the name of the young pilgrim that Prince Andrew glanced '
#  'at with a smile?\n'
#  'answer: Ivanushka']

# %% [markdown]
# ## End of the notebook
#
# Check more Uniflow use cases in the [example folder](https://github.com/CambioML/uniflow/tree/main/example/model#examples)!
#
# <a href="https://www.cambioml.com/" title="Title">
#     <img src="../image/cambioml_logo_large.png" style="height: 100px; display: block; margin-left: auto; margin-right: auto;"/>
# </a>
